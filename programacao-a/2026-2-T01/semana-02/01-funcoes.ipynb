# %% [markdown]
# # Definição de funções
# Duas funções matemáticas.
# <!--
#   Sugestão: Apresentar antes no quadro o conceito de função e como são definidas na matemática.
#              Pode apresentar um diagrama de uma função e a representação matemática.
#              Por ex:
#                f : Z -> Z
#                f(x) = 2*x
#              Junto com o diagrama.
#
#   Aproveitar o exemplo para falar algo sobre escopos. Destacar que, apesar do nome do parâmetros de dobro e triplo ser o mesmo, elas são variáveis distintas
# -->

# %%
def dobro(n) :
    return 2*n

def triplo(n) :
    return 3*n

print(dobro(5) + triplo(5))
print(dobro(25))
# Out:
# 25
# 50

# %% [markdown]
# Como outro exemplo, escrevamos um programa que leia a altura e o raio da base de um cilindro e que então calcule qual é a área do cilindro.
# <!--  Apresentar de forma top down: começar primeiro com o return e depois as linhas para areaLateral e areaBase
#
#       Destacar o import caso não tenha sido introduzido antes
# -->

# %%
from math import pi

def areaCilindro(a, r) :
    areaLateral = 2*pi*r*a
    areaBase = pi*r**2
    return areaLateral + 2*areaBase

altura = float(input())
raio = float(input())
print(areaCilindro(altura, raio))
# Out:
# 678.5840131753953

# %% [markdown]
# Usando procedimentos, definamos um script que apresenta duas casas.
# <!-- Apresentar de forma top-down.
#      1) Explicar qual é o resultado que esperamos
#      2) Iniciar a explicação do programa pelo script principal
#      3) Depois casa e só depois parede e teto.
#
#      Destacar parametrização. Conseguimos genericidade.
#      Destacar, no final, que a construção foi feita passo a passo, abstraindo através de funções auxiliares.
# -->

# %%
def parede(c) :
    print(c*9)
    print(c*9)
    print(c*3 + " "*3 + c*3)
    print(c*3 + " "*3 + c*3)

def teto(c) :
    print(" "*4 + c)
    print(" "*2 + c*5)
    print(c*9)

def casa(p, t) :
    teto(t)
    parede(p)

casa("#", "%")
print()
casa("+", "*")
# Out:
#     %
#   %%%%%
# %%%%%%%%%
# #########
# #########
# ###   ###
# ###   ###
#
#     *
#   *****
# *********
# +++++++++
# +++++++++
# +++   +++
# +++   +++

# %% [markdown]
# Algumas observações sobre o código anterior.
#   + O código foi dividido ou estruturado usando funções.
#   + O uso de nomes significativos para as funções é crucial para o entendimento do programa por parte de outros programadores.
#   + O programa principal, linhas 16-17, expressa claramente a intenção, apresentar duas casas separada por uma linha em branco.
#   + Da mesma forma, a intenção da função `casa` é clara. Primeiro apresenta-se o teto e depois a parede.
#   + As funções `parede` e `teto` estão parametrizadas pelo caracter que será usado na apresentação. Isto permite reusar o mesmo código para casas com caracteres diversos para apresentar tanto a parede como o teto.
#   + Para alguém que lê o código, o entendimento é modular.
#
# Sobre entendimento modular, a recomendação é iniciar a leitura do programa pelo programa principal. No caso, as linhas 16-17. Se apenas interessa um entendimento de mais alto nível, a leitura pode terminar aqui. Porém, se interessam os detalhes, a leitura pode continuar para a definição de `casa`. A definição de `casa` diz que primeiro apresenta-se o teto e logo depois a parede. Por sua vez, a apresentação de teto e  parede estão encapsuladas em duas funções separadas. Se o leitor quiser mais detalhes, ele pode então partir para a leitura das definições das funções correspondentes, `teto` e `parede`.
# Seguindo esta abordagem de leitura, o entendimento completo do programa se dá por camadas, primeiro obtem-se um entendimento geral e abstrato, de alto nível. Depois, podem se entender detalhes, descendo a um nível mais baixo, olhando as respectivas definições.
#
# A divisão do programa em funções não só permite entender partes do programa por separado, mas também permite testar e depurar peças de código por separado.
#
# ## Execução de programas passo a passo com o depurador
# <!--
# Usar o depurador para mostrar
#   - mecanismo de passagem de parâmetros
#   - tempo de vida de parâmetros e variáveis locais
#   - pilha de frames
# -->

# %% [markdown]
# ## Exercícios
# 1) Faça um script que leia três notas de um aluno e calcule a média. O script deve definir uma função que calcule a média de três notas quaisquer.

# %%
# Escreva aqui sua solução
def media (n1, n2, n3):
  return (n1 + n2 + n3)/3
n1 = float(input("digite nota 1:"))
n2 = float(input("digite nota 2:"))
n3 = float(input("digite nota 3:"))
print(f"A media das notas é: {media(n1, n2, n3):.2f}")
# Out:
# digite nota 1:7.2
# digite nota 2:8.2
# digite nota 3:4.3
# A media das notas é: 6.57

# %% [markdown]
# 2) Todo proprietário de véiculo deve pagar a cada ano o Imposto sobre a Propriedade de Veículos Automotores (IPVA) junto com a taxa de Licenciamento Anual (CRLV-e). Em um estado da federação, quando se opta por pagar antes do prazo, há um desconto de 10% no valor do IPVA.  Escreva um programa que leia o valor do IPVA sem desconto e o valor do CRLV-e e que escreva na tela quanto o proprietário vai pagar com desconto e sem desconto. Seu programa deve ter duas funções, uma para calcular o valor total sem desconto e outro para calcular o valor total com desconto.

# %%
# escreva aqui sua solução

ipva = float(input("DIGITE VALOR IPVA:"))
crlv = float(input("DIGITE VALOR CRLV:"))
def total(ipva,crlv):
  return ipva + crlv
print(f"VALOR IPVA TOTAL: {total(ipva,crlv):.2f}")
def desconto(ipva,crlv):
  return (ipva * 1.1) + crlv
print(f"VALOR COM DESCONTO:{desconto(ipva,crlv):.2f}")
# Out:
# DIGITE VALOR IPVA:800
# DIGITE VALOR CRLV:60
# VALOR IPVA TOTAL: 860.00
# VALOR COM DESCONTO:940.00

# %% [markdown]
# 3) Em outro estado da federação, o desconto de 10% é aplicado ao valor total (IPVA + CRLV-e). Altere o programa anterior para este estado.

# %%
# escreva aqui sua solução
ipva = float(input("DIGITE VALOR IPVA:"))
crlv = float(input("DIGITE VALOR CRLV:"))
def total(ipva,crlv):
  return ipva + crlv
print(f"VALOR IPVA TOTAL: {total(ipva,crlv):.2f}")
def desconto(ipva,crlv):
  return (ipva + crlv) *1.1
print(f"VALOR COM DESCONTO:{desconto(ipva,crlv):.2f}")
# Out:
# DIGITE VALOR IPVA:800
# DIGITE VALOR CRLV:60
# VALOR IPVA TOTAL: 860.00
# VALOR COM DESCONTO:946.00

# %% [markdown]
# 4) Elabore um script que permita calcular a distância entre dois pontos no plano. O script receberá como entrada valores para x1, y1, x2 e y2 e então calculará a distância entre os pontos (x1, y1) e (x2, y2). Seu script deve definir uma função que calcule a distância entre dois pontos dados.

# %%
# escreva aqui sua solução
x1 = float(input("Digite x1:"))
y1 = float(input("Digite x2:"))
x2 = float(input("Digite y1:"))
y2 = float(input("Digite y2:"))

def distancia(x1, y1, x2, y2) :
    return ((x2-x1)**2 + (y2-y1)**2)**0.5

print(f"A distancia entre os pontos é: {distancia(x1, y1, x2, y2):.2f}")
# Out:
# Digite x1:1
# Digite x2:1
# Digite y1:3
# Digite y2:1
# 2.00

# %% [markdown]
# 5) Usando como modelo o programa acima que apresenta casas, elabore um programa que permita apresentar igrejas católicas. Uma igreja católica é similar com uma casa, porém tem uma cruz acima do telhado. Permita que possa ser escolhido o caracter usado para apresentar a cruz. O script deverá apresentar duas igrejas usando caracteres diferentes.

# %%
# escreva
def cruz (c):
  print(" "*9 + "†" + " " * 6+ " " * 4 + caractere_cruz * 2 )
  print(" "*9 + c + " " * 5 + " " * 1 + caractere_cruz * 9 )
  print(" "*8 + c * 3 + " "*4 + " " * 1 + caractere_cruz * 9 )
  print(" "*7 + c * 5 + " "*4 + " " * 4 + caractere_cruz *2 )
  print(" "*6 + c * 7 + " "*3 + " " * 4 + caractere_cruz * 2 )
  print(" "*5 + c * 9 + " "*2 + " " * 4 + caractere_cruz * 2 )
  print(" " * 3 + c * 13 + " " * 4 + caractere_cruz * 2 )
def parede (c):
  print(" " * 2 +c * 23)
  print(" " * 2 +c * 23)
  print(" " * 2 + c* 2 + " "*4 + c * 7 + " "*3 + c * 7 )
  print(" " * 2 +c * 2 + " "*4 + c * 7 + " "*3 + c * 7 )
  print(" " * 2 +c * 2 + " "*4 + c * 17 )
  print(c * 26)
def igreja1(c_cruz, p):
  c_cruz = input("Digite o caractere da Cruz:")
  cruz(c_cruz)
  parede(p)
igreja1("","O")
def igreja2(c_cruz, q):
  c_cruz = input("Digite o caractere da Cruz:")
  cruz(c_cruz)
  parede(q)
igreja2("","O")
print()
# Out:
# Digite o caractere da Cruz:x
#          †          xx
#          x      xxxxxxxxx
#         xxx     xxxxxxxxx
#        xxxxx        xx
#       xxxxxxx       xx
#      xxxxxxxxx      xx
#    xxxxxxxxxxxxx    xx
#   OOOOOOOOOOOOOOOOOOOOOOO
#   OOOOOOOOOOOOOOOOOOOOOOO
#   OO    OOOOOOO   OOOOOOO
#   OO    OOOOOOO   OOOOOOO
#   OO    OOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOO
# Digite o caractere da Cruz:h
#          †          xx
#          h      xxxxxxxxx
#         hhh     xxxxxxxxx
#        hhhhh        xx
#       hhhhhhh       xx
#      hhhhhhhhh      xx
#    hhhhhhhhhhhhh    xx
#   OOOOOOOOOOOOOOOOOOOOOOO
#   OOOOOOOOOOOOOOOOOOOOOOO
#   OO    OOOOOOO   OOOOOOO
#   OO    OOOOOOO   OOOOOOO
#   OO    OOOOOOOOOOOOOOOOO
# OOOOOOOOOOOOOOOOOOOOOOOOOO

# %% [markdown]
# 6) Utilize o depurador para executar passo a passo o programa anterior. Preste atenção aos valores dos parâmetros e a pilha de chamadas.

# %%
# escreva aqui sua solução
